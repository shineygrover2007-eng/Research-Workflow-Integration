# %%
# COVID-19 Data Analysis Mini Project

import pandas as pd
import matplotlib.pyplot as plt

# Load sample COVID dataset (from online source)
url = "https://raw.githubusercontent.com/datasets/covid-19/main/data/countries-aggregated.csv"
df = pd.read_csv(url)

# Preview data
print("Dataset Preview:")
print(df.head())

# Filter for India
india = df[df["Country"] == "India"]

# Plot Confirmed cases over time
plt.figure(figsize=(10,5))
plt.plot(india["Date"], india["Confirmed"], label="Confirmed Cases")
plt.plot(india["Date"], india["Recovered"], label="Recovered Cases")
plt.plot(india["Date"], india["Deaths"], label="Deaths")
plt.xlabel("Date")
plt.ylabel("Cases")
plt.title("COVID-19 Trends in India")
plt.legend()
plt.show()
# Out:
# Dataset Preview:
#          Date      Country  Confirmed  Recovered  Deaths
# 0  2020-01-22  Afghanistan          0          0       0
# 1  2020-01-23  Afghanistan          0          0       0
# 2  2020-01-24  Afghanistan          0          0       0
# 3  2020-01-25  Afghanistan          0          0       0
# 4  2020-01-26  Afghanistan          0          0       0
